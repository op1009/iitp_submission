# %%
# !huggingface-cli login
# Out:
# ⚠️  Warning: 'huggingface-cli login' is deprecated. Use 'hf auth login' instead.
#
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `hf auth whoami` to get more information or `hf auth logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: read).
# The token `iitp_test` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `iitp_test`

# %%
from datasets import load_dataset

ds = load_dataset("ainlpml/english-hindi")
# Out:
# eng.txt:   0%|          | 0.00/1.01M [00:00<?, ?B/s]
# hin.txt:   0%|          | 0.00/2.45M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/20000 [00:00<?, ? examples/s]

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 20000
#     })
# })

# %%
import pandas as pd

train_df = ds["train"].to_pandas()

# %%
train_df
# Out:
#                                                     text
# 0      However, Paes, who was partnering Australia's ...
# 1      Whosoever desires the reward of the world, wit...
# 2      "The value of insects in the biosphere is enor...
# 3      Mithali To Anchor Indian Team Against Australi...
# 4      After the assent of the Honble President on 8t...
# ...                                                  ...
# 19995  इन चंद, चुनिंदा शब्दों से बुद्धिमान राजा सुलैम...
# 19996  पुलिस ने युवकों का पीछा कर दो युवकों को हिरासत...
# 19997  में मुर्गीपालन से प्राप्त मांस तथा गाद का अनुम...
# 19998  सबसे पहले ऑफिशियल वेबसाइट education. rajasthan...
# 19999  डिस्क्लेमर : अनिल अंबानी के रिलायंस ग्रुप ने N...
#
# [20000 rows x 1 columns]

# %%
col_eng = train_df.iloc[:10000].reset_index(drop=True)
col_hin = train_df.iloc[10000:].reset_index(drop=True)

# %%
df_trans = pd.concat([col_eng, col_hin], axis=1)

df_trans.columns = ['eng', 'hin']

# print(df_trans)
df_trans
# Out:
#                                                     eng  \
# 0     However, Paes, who was partnering Australia's ...
# 1     Whosoever desires the reward of the world, wit...
# 2     "The value of insects in the biosphere is enor...
# 3     Mithali To Anchor Indian Team Against Australi...
# 4     After the assent of the Honble President on 8t...
# ...                                                 ...
# 9995  With these few, well - chosen words, wise King...
# 9996  Police have arrested two people and apprehende...
# 9997  "The annual production of poultry meat in 1991...
# 9998  Step 1: Visit the official websites rsosapp.ra...
# 9999  Anil Ambanis Reliance Group has sued news chan...
#
#                                                     hin
# 0     आस्ट्रेलिया के पाल हेनली के साथ जोड़ी बनाने वाल...
# 1     और जो शख्स (अपने आमाल का) बदला दुनिया ही में च...
# 2     जैव-मंडल में कीड़ों का मूल्य बहुत है, क्योंकि ...
# 3      आस्ट्रेलिया के खिलाफ वनडे टीम की कमान मिताली को
# 4     8 सितम्‍बर, 2016 को माननीय राष्‍ट्रपति की स्‍व...
# ...                                                 ...
# 9995  इन चंद, चुनिंदा शब्दों से बुद्धिमान राजा सुलैम...
# 9996  पुलिस ने युवकों का पीछा कर दो युवकों को हिरासत...
# 9997  में मुर्गीपालन से प्राप्त मांस तथा गाद का अनुम...
# 9998  सबसे पहले ऑफिशियल वेबसाइट education. rajasthan...
# 9999  डिस्क्लेमर : अनिल अंबानी के रिलायंस ग्रुप ने N...
#
# [10000 rows x 2 columns]

# %%
df_trans['count_eng'] = df_trans['eng'].str.len()
df_trans['count_hin'] = df_trans['hin'].str.len()

# %%
df_trans
# Out:
#                                                     eng  \
# 0     However, Paes, who was partnering Australia's ...
# 1     Whosoever desires the reward of the world, wit...
# 2     "The value of insects in the biosphere is enor...
# 3     Mithali To Anchor Indian Team Against Australi...
# 4     After the assent of the Honble President on 8t...
# ...                                                 ...
# 9995  With these few, well - chosen words, wise King...
# 9996  Police have arrested two people and apprehende...
# 9997  "The annual production of poultry meat in 1991...
# 9998  Step 1: Visit the official websites rsosapp.ra...
# 9999  Anil Ambanis Reliance Group has sued news chan...
#
#                                                     hin  count_eng  count_hin
# 0     आस्ट्रेलिया के पाल हेनली के साथ जोड़ी बनाने वाल...        141        147
# 1     और जो शख्स (अपने आमाल का) बदला दुनिया ही में च...        141        155
# 2     जैव-मंडल में कीड़ों का मूल्य बहुत है, क्योंकि ...        130        124
# 3      आस्ट्रेलिया के खिलाफ वनडे टीम की कमान मिताली को          56         48
# 4     8 सितम्‍बर, 2016 को माननीय राष्‍ट्रपति की स्‍व...        128        119
# ...                                                 ...        ...        ...
# 9995  इन चंद, चुनिंदा शब्दों से बुद्धिमान राजा सुलैम...        171        185
# 9996  पुलिस ने युवकों का पीछा कर दो युवकों को हिरासत...         66         63
# 9997  में मुर्गीपालन से प्राप्त मांस तथा गाद का अनुम...        133        118
# 9998  सबसे पहले ऑफिशियल वेबसाइट education. rajasthan...        113         70
# 9999  डिस्क्लेमर : अनिल अंबानी के रिलायंस ग्रुप ने N...        155        119
#
# [10000 rows x 4 columns]

# %%
df_filtered = df_trans[((df_trans['count_eng'] >= 5) & (df_trans['count_eng'] <= 50)) & ((df_trans['count_hin'] >= 5) & (df_trans['count_hin'] <= 50))]

df_filtered
# Out:
#                                                  eng  \
# 8             Jharkhand chief minister Hemant Soren
# 13    Meanwhile, three people came there on a bike.
# 18                                     Share videos
# 23                     "They are not seen anywhere.
# 27                       Both are safe and healthy.
# ...                                              ...
# 9979                              Video/photography
# 9982               Total collection - Rs 9.90 crore
# 9985    In fact, he was very generous of the heart.
# 9991        "The cases against him are not ordinary
# 9994          Everything is changing with the time.
#
#                                                     hin  count_eng  count_hin
# 8     झारखंड के मुख्यमंत्री हेमंत सोरेन (फोटोः पीटीआई)          38         49
# 13           इसी बीच एक बाइक पर तीन लोग आते दिखाई दिए।          46         42
# 18                               वीडियो क्लिप शेयर किए          13         22
# 23                 दोनों ही कहीं भी दिखाई नहीं पड़ रहे।          29         36
# 27                   सभी सुरक्षित और खतरे से बाहर हैं।          27         34
# ...                                                 ...        ...        ...
# 9979                            फोटो और वीडियो स्त्रोत          18         23
# 9982                             कुल जमा9.90 करोड़ रूपए          33         22
# 9985                   वास्तव में, वह बड़े दिलवाले थे.          44         32
# 9991                फ़िलहाल आने वाले मामले आम नहीं हैं          40         35
# 9994                        समय के साथ सब बदल जाता है.          38         27
#
# [2514 rows x 4 columns]

# %%
df_filtered['diff'] = df_filtered['count_eng'] - df_filtered['count_hin']
# Out:
# /tmp/ipython-input-1333776866.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['diff'] = df_filtered['count_eng'] - df_filtered['count_hin']

# %%
df_filtered
# Out:
#                                                  eng  \
# 8             Jharkhand chief minister Hemant Soren
# 13    Meanwhile, three people came there on a bike.
# 18                                     Share videos
# 23                     "They are not seen anywhere.
# 27                       Both are safe and healthy.
# ...                                              ...
# 9979                              Video/photography
# 9982               Total collection - Rs 9.90 crore
# 9985    In fact, he was very generous of the heart.
# 9991        "The cases against him are not ordinary
# 9994          Everything is changing with the time.
#
#                                                     hin  count_eng  count_hin  \
# 8     झारखंड के मुख्यमंत्री हेमंत सोरेन (फोटोः पीटीआई)          38         49
# 13           इसी बीच एक बाइक पर तीन लोग आते दिखाई दिए।          46         42
# 18                               वीडियो क्लिप शेयर किए          13         22
# 23                 दोनों ही कहीं भी दिखाई नहीं पड़ रहे।          29         36
# 27                   सभी सुरक्षित और खतरे से बाहर हैं।          27         34
# ...                                                 ...        ...        ...
# 9979                            फोटो और वीडियो स्त्रोत          18         23
# 9982                             कुल जमा9.90 करोड़ रूपए          33         22
# 9985                   वास्तव में, वह बड़े दिलवाले थे.          44         32
# 9991                फ़िलहाल आने वाले मामले आम नहीं हैं          40         35
# 9994                        समय के साथ सब बदल जाता है.          38         27
#
#       diff
# 8      -11
# 13       4
# 18      -9
# 23      -7
# 27      -7
# ...    ...
# 9979    -5
# 9982    11
# 9985    12
# 9991     5
# 9994    11
#
# [2514 rows x 5 columns]

# %%
df_filtered = df_filtered[((df_filtered['diff'] >= -10) & (df_filtered['diff'] <= 10))]
df_filtered
# Out:
#                                                  eng  \
# 13    Meanwhile, three people came there on a bike.
# 18                                     Share videos
# 23                     "They are not seen anywhere.
# 27                       Both are safe and healthy.
# 34                     Im fine by the grace of God.
# ...                                              ...
# 9975                                    What is it?
# 9976                     She is not informed of it.
# 9977                I want things to keep evolving.
# 9979                              Video/photography
# 9991        "The cases against him are not ordinary
#
#                                              hin  count_eng  count_hin  diff
# 13    इसी बीच एक बाइक पर तीन लोग आते दिखाई दिए।          46         42     4
# 18                        वीडियो क्लिप शेयर किए          13         22    -9
# 23          दोनों ही कहीं भी दिखाई नहीं पड़ रहे।          29         36    -7
# 27            सभी सुरक्षित और खतरे से बाहर हैं।          27         34    -7
# 34        ईश्वर की कृपा से मैं बिल्कुल ठीक हूं.          29         38    -9
# ...                                          ...        ...        ...   ...
# 9975                           ~ तुरंत क्या है?          12         17    -5
# 9976                     उसे इसकी कोई खबर नहीं।          27         23     4
# 9977             मैं चाहता हूं कि बात आगे बढ़े.          32         31     1
# 9979                     फोटो और वीडियो स्त्रोत          18         23    -5
# 9991         फ़िलहाल आने वाले मामले आम नहीं हैं          40         35     5
#
# [2083 rows x 5 columns]

# %%
df_filtered.columns = ["English Sentences", "Hindi Sentences", "Word Count (English)", "Word Count (Hindi)", "Difference between Word Count (English) and Word Count (Hindi)"]

# %%
df_filtered
# Out:
#                                    English Sentences  \
# 13    Meanwhile, three people came there on a bike.
# 18                                     Share videos
# 23                     "They are not seen anywhere.
# 27                       Both are safe and healthy.
# 34                     Im fine by the grace of God.
# ...                                              ...
# 9975                                    What is it?
# 9976                     She is not informed of it.
# 9977                I want things to keep evolving.
# 9979                              Video/photography
# 9991        "The cases against him are not ordinary
#
#                                  Hindi Sentences  Word Count (English)  \
# 13    इसी बीच एक बाइक पर तीन लोग आते दिखाई दिए।                     46
# 18                        वीडियो क्लिप शेयर किए                     13
# 23          दोनों ही कहीं भी दिखाई नहीं पड़ रहे।                     29
# 27            सभी सुरक्षित और खतरे से बाहर हैं।                     27
# 34        ईश्वर की कृपा से मैं बिल्कुल ठीक हूं.                     29
# ...                                          ...                   ...
# 9975                           ~ तुरंत क्या है?                     12
# 9976                     उसे इसकी कोई खबर नहीं।                     27
# 9977             मैं चाहता हूं कि बात आगे बढ़े.                     32
# 9979                     फोटो और वीडियो स्त्रोत                     18
# 9991         फ़िलहाल आने वाले मामले आम नहीं हैं                     40
#
#       Word Count (Hindi)  \
# 13                    42
# 18                    22
# 23                    36
# 27                    34
# 34                    38
# ...                  ...
# 9975                  17
# 9976                  23
# 9977                  31
# 9979                  23
# 9991                  35
#
#       Difference between Word Count (English) and Word Count (Hindi)
# 13                                                    4
# 18                                                   -9
# 23                                                   -7
# 27                                                   -7
# 34                                                   -9
# ...                                                 ...
# 9975                                                 -5
# 9976                                                  4
# 9977                                                  1
# 9979                                                 -5
# 9991                                                  5
#
# [2083 rows x 5 columns]

# %%
df_filtered.to_csv('cleaned_dataset.csv')
